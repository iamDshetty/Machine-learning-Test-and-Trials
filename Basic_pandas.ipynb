# %%
people = {'name':['chandrashekar','rajashekar','ravikiran','mithu','ritesh','manvith'],
          'age':[29,26,28,22,30,30],
          'location':['Bengaluru','Bengaluru','Bengaluru','hebri','udupi','Germany']}
people
# Out:
# {'name': ['chandrashekar',
#   'rajashekar',
#   'ravikiran',
#   'mithu',
#   'ritesh',
#   'manvith'],
#  'age': [29, 26, 28, 22, 30, 30],
#  'location': ['Bengaluru',
#   'Bengaluru',
#   'Bengaluru',
#   'hebri',
#   'udupi',
#   'Germany']}

# %%
import pandas as pd

df = pd.DataFrame(people)

df
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df['name']  # this is series i.e.., single column or  df.age -dot notation
#df.head()
#df.info()
#df.describe()
# Out:
# 0    chandrashekar
# 1       rajashekar
# 2        ravikiran
# 3            mithu
# 4           ritesh
# 5          manvith
# Name: name, dtype: object

# %%
df[['name','age']]
# Out:
#             name  age
# 0  chandrashekar   29
# 1     rajashekar   26
# 2      ravikiran   28
# 3          mithu   22
# 4         ritesh   30
# 5        manvith   30

# %%
df.columns
# Out:
# Index(['name', 'age', 'location'], dtype='object')

# %%
df.iloc[0] #first row
# Out:
# name        chandrashekar
# age                    29
# location        Bengaluru
# Name: 0, dtype: object

# %%
df.iloc[:,:]  # rows,columns
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df.iloc[0,0] # Display 0 row , 0 column
# Out:
# 'chandrashekar'

# %%
df.iloc[[0,1],2]  # only disply 3 column in dataframe
# Out:
# 0    Bengaluru
# 1    Bengaluru
# Name: location, dtype: object

# %%
df.loc[0] #loc vs iloc //  iloc takes integers only
# Out:
# name        chandrashekar
# age                    29
# location        Bengaluru
# Name: 0, dtype: object

# %%
df.loc[[0,1],'age']
# Out:
# 0    29
# 1    26
# Name: age, dtype: int64

# %%
df.loc[[0,1],['location','age']]

df['location'].value_counts()   #counts how many times the value in a column occured
# Out:
# Bengaluru    3
# hebri        1
# Germany      1
# udupi        1
# Name: location, dtype: int64

# %%
df.iloc[0].value_counts() #counts how many times the value in a row occured
# Out:
# Bengaluru        1
# chandrashekar    1
# 29               1
# Name: 0, dtype: int64

# %%
df.loc[[0,1,3],"age"]   # required row can be chosen using list
# Out:
# 0    29
# 1    26
# 3    22
# Name: age, dtype: int64

# %%
df.loc[[0,1,3],"name":'location']   # required row can be chosen as well as columns in between
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 3          mithu   22      hebri

# %%
#index

df.set_index('name') # to change index,,,name is selected because in this example its unique .index better to unique
# Out:
#                age   location
# name
# chandrashekar   29  Bengaluru
# rajashekar      26  Bengaluru
# ravikiran       28  Bengaluru
# mithu           22      hebri
# ritesh          30      udupi
# manvith         30    Germany

# %%
df # but after above index df is not chnaged
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df.set_index("name",inplace =True)  # inplace = True will change index permanetnly in df 
df
# Out:
#                age   location
# name
# chandrashekar   29  Bengaluru
# rajashekar      26  Bengaluru
# ravikiran       28  Bengaluru
# mithu           22      hebri
# ritesh          30      udupi
# manvith         30    Germany

# %%
df.index #to check the index
# Out:
# Index(['chandrashekar', 'rajashekar', 'ravikiran', 'mithu', 'ritesh',
#        'manvith'],
#       dtype='object', name='name')

# %%
df.loc['mithu']
# Out:
# age            22
# location    hebri
# Name: mithu, dtype: object

# %%
df.loc['mithu','age']
# Out:
# 22

# %%
df.reset_index(inplace=True)  #reset index to original
df
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df_i = pd.read_csv('D:/Chandrashekar S/New Volume/Machine learning/Mathematics  in Python/Linear Regression/datasets/titanicfull.csv'
                   ,index_col = 'name') #while reading file we can set arg 'index_col' to change index to specific column
df_i.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
#
#                                                    age  sibsp  parch  ticket  \
# name
# Allen, Miss. Elisabeth Walton                    29.00      0      0   24160
# Allison, Master. Hudson Trevor                    0.92      1      2  113781
# Allison, Miss. Helen Loraine                      2.00      1      2  113781
# Allison, Mr. Hudson Joshua Creighton             30.00      1      2  113781
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00      1      2  113781
#
# ...

# %%
#df.set_index('name',inplace=True)

# %%
df.sort_index()  #sorting the index
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df.sort_index(ascending=False)  #to sort in descending order
# Out:
#             name  age   location
# 5        manvith   30    Germany
# 4         ritesh   30      udupi
# 3          mithu   22      hebri
# 2      ravikiran   28  Bengaluru
# 1     rajashekar   26  Bengaluru
# 0  chandrashekar   29  Bengaluru

# %%
df.sort_index(inplace=True)  # permanently change the index with sort in ascending order
df
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df = pd.read_csv('D:/Chandrashekar S/New Volume/Machine learning/Mathematics  in Python/Linear Regression/datasets/titanicfull.csv'
                   )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   name      1309 non-null   object
#  3   sex       1309 non-null   object
#  4   age       1046 non-null   float64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   object
#  8   fare      1308 non-null   float64
#  9   cabin     295 non-null    object
#  10  embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
male = df['sex'] =="male"
male
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306     True
# 1307     True
# 1308     True
# Name: sex, Length: 1309, dtype: bool

# %%
df[male]  # or df["sex"]=='male' or df.loc[male,'age']
# Out:
#       pclass  survived                                  name   sex    age  \
# 1          1         1        Allison, Master. Hudson Trevor  male   0.92
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male  30.00
# 5          1         1                   Anderson, Mr. Harry  male  48.00
# 7          1         0                Andrews, Mr. Thomas Jr  male  39.00
# 9          1         0               Artagaveytia, Mr. Ramon  male  71.00
# ...      ...       ...                                   ...   ...    ...
# 1302       3         0                     Yousif, Mr. Wazli  male    NaN
# 1303       3         0                 Yousseff, Mr. Gerious  male    NaN
# 1306       3         0             Zakarian, Mr. Mapriededer  male  26.50
# 1307       3         0                   Zakarian, Mr. Ortin  male  27.00
# 1308       3         0                    Zimmerman, Mr. Leo  male  29.00
#
#       sibsp  parch    ticket      fare    cabin embarked
# ...

# %%
df.loc[male,'age']  #filter male with age
# Out:
# 1        0.92
# 3       30.00
# 5       48.00
# 7       39.00
# 9       71.00
#         ...
# 1302      NaN
# 1303      NaN
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 843, dtype: float64

# %%
 male_age = (df["sex"]=='male') & (df['age']==30)  # filter sex==male &(AND) age==30   

df.loc[male_age,'name']   #find above filter with name , so answer will be list of names of male of 30 age
# Out:
# 3         Allison, Mr. Hudson Joshua Creighton
# 110            Foreman, Mr. Benjamin Laventall
# 191                 Loring, Mr. Joseph Holland
# 194                   Maguire, Mr. John Edward
# 209                   Mock, Mr. Philipp Edmund
# 323                        Abelson, Mr. Samuel
# 325             Aldworth, Mr. Charles Augustus
# 424                Givard, Mr. Hans Kristensen
# 426                         Hale, Mr. Reginald
# 433                         Harris, Mr. Walter
# 476                     Lahtinen, Rev. William
# 496                 Matthews, Mr. William John
# 499                  McCrie, Mr. James Matthew
# 538     Portaluppi, Mr. Emilio Ilario Giuseppe
# 578                       Ware, Mr. John James
# 608             Adahl, Mr. Mauritz Nils Martin
# 651                       Attalah, Mr. Sleiman
# 732                            Corn, Mr. Harry
# 760                    de Mulder, Mr. Theodore
# 875               Ibrahim Shawah, Mr. Yousseff
# ...

# %%
df.loc[~male_age,'name']  # ~ oppsite values so except male and age 30
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5                                   Anderson, Mr. Harry
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1286, dtype: object

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %%
f=df.loc[df['fare'] > 200]   
f.info()
f
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 314
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    38 non-null     int64
#  1   survived  38 non-null     int64
#  2   name      38 non-null     object
#  3   sex       38 non-null     object
#  4   age       36 non-null     float64
#  5   sibsp     38 non-null     int64
#  6   parch     38 non-null     int64
#  7   ticket    38 non-null     object
#  8   fare      38 non-null     float64
#  9   cabin     33 non-null     object
#  10  embarked  38 non-null     object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 3.6+ KB
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
pclass = [20,25,30]
filt  = df['age'].isin(pclass)
df.loc[filt,'fare']
# Out:
# 3       151.5500
# 4       151.5500
# 25       26.0000
# 26       91.0792
# 32      164.8667
#           ...
# 1234      7.0500
# 1238      7.7958
# 1254      0.0000
# 1267     24.1500
# 1278      7.8542
# Name: fare, Length: 97, dtype: float64

# %%
filt = df['name'].str.contains('Allison|Widener',na=False)    
df.loc[filt,'name']
# Out:
# 1                       Allison, Master. Hudson Trevor
# 2                         Allison, Miss. Helen Loraine
# 3                 Allison, Mr. Hudson Joshua Creighton
# 4      Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 312                         Widener, Mr. George Dunton
# 313                          Widener, Mr. Harry Elkins
# 314       Widener, Mrs. George Dunton (Eleanor Elkins)
# Name: name, dtype: object

# %%
#updating rows and columns

# %%
df  = pd.DataFrame(people)
df
# Out:
#             name  age   location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df.columns = ["First name",'my age','location']
df
# Out:
#       First name  my age   location
# 0  chandrashekar      29  Bengaluru
# 1     rajashekar      26  Bengaluru
# 2      ravikiran      28  Bengaluru
# 3          mithu      22      hebri
# 4         ritesh      30      udupi
# 5        manvith      30    Germany

# %%
df.columns = [x.upper() for x in df.columns] # this is called list comprehension
df
# Out:
#       FIRST NAME  MY AGE   LOCATION
# 0  chandrashekar      29  Bengaluru
# 1     rajashekar      26  Bengaluru
# 2      ravikiran      28  Bengaluru
# 3          mithu      22      hebri
# 4         ritesh      30      udupi
# 5        manvith      30    Germany

# %%
df.columns = df.columns.str.replace('','_')  # replaces empty  spaces with underscore
df
# Out:
#       FIRST NAME  MY AGE   LOCATION
# 0  chandrashekar      29  Bengaluru
# 1     rajashekar      26  Bengaluru
# 2      ravikiran      28  Bengaluru
# 3          mithu      22      hebri
# 4         ritesh      30      udupi
# 5        manvith      30    Germany

# %%
df.rename(columns = {'FIRST NAME':'Name','MY AGE': 'age','LOCATION':'Location'},inplace=True)
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df.loc[0,'age']  = 30  #change specific cell
df
# Out:
#             Name  age   Location
# 0  chandrashekar   30  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df.at[0,'age'] = 29 #change specific cell value using 'at'
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df['Location'].str.lower()  #all values in column Location is converted to lowercase
# df['location'] = df['location'].str.lower() # permenentaley change the values of location column
# Out:
# 0    bengaluru
# 1    bengaluru
# 2    bengaluru
# 3        hebri
# 4        udupi
# 5      germany
# Name: Location, dtype: object

# %%
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
#update multiple cells
#methods
#  1.apply()  #apply for scpecific column or all columns headers only
#  2.map()  #works with series only and all values has to be dictioned other wise returns nan
#  3.applymap() #works with dataframes only
# 4. replace()  # a specific value can be replaced in a specified column

# %%
def upper_location(location):
    return location.upper()

df['Location'].apply(upper_location)   # column 'Location'  is apply by a function which converts to upper case
#df['location'].aplly(len)  #any function can be applied.. here inbuilt function len is applied 
df['Location'].apply(lambda x: x.lower())   #lamba is funtion without name in python
# Out:
# 0    bengaluru
# 1    bengaluru
# 2    bengaluru
# 3        hebri
# 4        udupi
# 5      germany
# Name: Location, dtype: object

# %%
df.apply(len)  # returns length of each column
# Out:
# Name        6
# age         6
# Location    6
# dtype: int64

# %%
df.apply(len,axis=1)   # returns length of each rows
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
df['Name'].map({'mithu':'pathu'})  #nan will be applied for non specified values
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3    pathu
# 4      NaN
# 5      NaN
# Name: Name, dtype: object

# %%
df['Name'].replace({'mithu':'pathu'}) # using replace a specific value can be replaced
# Out:
# 0    chandrashekar
# 1       rajashekar
# 2        ravikiran
# 3            pathu
# 4           ritesh
# 5          manvith
# Name: Name, dtype: object

# %%
#add or remove rows and column

# %%
df['name_location']  = df['Name']+','+df['Location']
df
# Out:
#             Name  age   Location            name_location
# 0  chandrashekar   29  Bengaluru  chandrashekar,Bengaluru
# 1     rajashekar   26  Bengaluru     rajashekar,Bengaluru
# 2      ravikiran   28  Bengaluru      ravikiran,Bengaluru
# 3          mithu   22      hebri              mithu,hebri
# 4         ritesh   30      udupi             ritesh,udupi
# 5        manvith   30    Germany          manvith,Germany

# %%
df['name_age'] = df['Name']+','+df['age'].astype(str)  #create a new column with concatinate of 2 columns .

#column age was having intergers so converted that as str using astype(str)
df
# Out:
#             Name  age   Location            name_location          name_age
# 0  chandrashekar   29  Bengaluru  chandrashekar,Bengaluru  chandrashekar,29
# 1     rajashekar   26  Bengaluru     rajashekar,Bengaluru     rajashekar,26
# 2      ravikiran   28  Bengaluru      ravikiran,Bengaluru      ravikiran,28
# 3          mithu   22      hebri              mithu,hebri          mithu,22
# 4         ritesh   30      udupi             ritesh,udupi         ritesh,30
# 5        manvith   30    Germany          manvith,Germany        manvith,30

# %%
df.drop(columns=['age','name_age'])  #inplace=True
# Out:
#             Name   Location            name_location
# 0  chandrashekar  Bengaluru  chandrashekar,Bengaluru
# 1     rajashekar  Bengaluru     rajashekar,Bengaluru
# 2      ravikiran  Bengaluru      ravikiran,Bengaluru
# 3          mithu      hebri              mithu,hebri
# 4         ritesh      udupi             ritesh,udupi
# 5        manvith    Germany          manvith,Germany

# %%
#df['name_age'] = df['name_age'].str.split(',')  #making a list inside a cell for that whole column
df
# Out:
#             Name  age   Location            name_location          name_age
# 0  chandrashekar   29  Bengaluru  chandrashekar,Bengaluru  chandrashekar,29
# 1     rajashekar   26  Bengaluru     rajashekar,Bengaluru     rajashekar,26
# 2      ravikiran   28  Bengaluru      ravikiran,Bengaluru      ravikiran,28
# 3          mithu   22      hebri              mithu,hebri          mithu,22
# 4         ritesh   30      udupi             ritesh,udupi         ritesh,30
# 5        manvith   30    Germany          manvith,Germany        manvith,30

# %%
df[['name1','age1']] = df['name_age'].str.split(',',expand=True)  # here make a list and expand  to other columns
df
# Out:
#             Name  age   Location            name_location          name_age  \
# 0  chandrashekar   29  Bengaluru  chandrashekar,Bengaluru  chandrashekar,29
# 1     rajashekar   26  Bengaluru     rajashekar,Bengaluru     rajashekar,26
# 2      ravikiran   28  Bengaluru      ravikiran,Bengaluru      ravikiran,28
# 3          mithu   22      hebri              mithu,hebri          mithu,22
# 4         ritesh   30      udupi             ritesh,udupi         ritesh,30
# 5        manvith   30    Germany          manvith,Germany        manvith,30
#
#            name1 age1
# 0  chandrashekar   29
# 1     rajashekar   26
# 2      ravikiran   28
# 3          mithu   22
# 4         ritesh   30
# 5        manvith   30

# %%
#  adding rows
df = df.drop(columns = ['name_age','name1','age1','name_location'])
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df = df.append({'Name':'pathu','age':22},ignore_index=True)  #Nan will be entered if no value is provided

# %%
df.at[6,'Location'] ="hebri"
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany
# 6          pathu   22      hebri

# %%
people2 = {'Name':['chandrashekar1','rajashekar','ravikiran','mithu','ritesh','manvith'],
          'age':[30,26,28,22,30,30]
          }

df2 = pd.DataFrame(people2)
df.append(df2,ignore_index=True,sort=False)


#df['Location']  = df['Location'].isnull()
#df
# Out:
#               Name  age   Location
# 0    chandrashekar   29  Bengaluru
# 1       rajashekar   26  Bengaluru
# 2        ravikiran   28  Bengaluru
# 3            mithu   22      hebri
# 4           ritesh   30      udupi
# 5          manvith   30    Germany
# 6            pathu   22      hebri
# 7   chandrashekar1   30        NaN
# 8       rajashekar   26        NaN
# 9        ravikiran   28        NaN
# 10           mithu   22        NaN
# 11          ritesh   30        NaN
# 12         manvith   30        NaN

# %%
#df.drop(index=4)  #drop  row
df
#df.drop(index=3)  #drop  row
df.drop(index=6)  #drop  row
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany
# 6          pathu   22      hebri

# %%
filt = df['Location']=="hebri" #filter 

df.drop(index=df[filt].index)  #index of filter removed
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany
# 6          pathu   22      hebri

# %%
df.sort_values(by=['Name'])
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 5        manvith   30    Germany
# 3          mithu   22      hebri
# 6          pathu   22      hebri
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 4         ritesh   30      udupi

# %%
df.sort_values(by=['Name','age'],ascending=[False,True],inplace=True)  # , inplace=True
df
# Out:
#             Name  age   Location
# 4         ritesh   30      udupi
# 2      ravikiran   28  Bengaluru
# 1     rajashekar   26  Bengaluru
# 6          pathu   22      hebri
# 3          mithu   22      hebri
# 5        manvith   30    Germany
# 0  chandrashekar   29  Bengaluru

# %%
df.sort_index()
# Out:
#             Name  age   Location
# 0  chandrashekar   29  Bengaluru
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 3          mithu   22      hebri
# 4         ritesh   30      udupi
# 5        manvith   30    Germany
# 6          pathu   22      hebri

# %%
 df.sort_values(by=['age'])
# Out:
#             Name  age   Location
# 6          pathu   22      hebri
# 3          mithu   22      hebri
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 0  chandrashekar   29  Bengaluru
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df[['age','Location']].sort_values(by=['age'])
# Out:
#    age   Location
# 6   22      hebri
# 3   22      hebri
# 1   26  Bengaluru
# 2   28  Bengaluru
# 0   29  Bengaluru
# 4   30      udupi
# 5   30    Germany

# %%
df
# Out:
#             Name  age   Location
# 4         ritesh   30      udupi
# 2      ravikiran   28  Bengaluru
# 1     rajashekar   26  Bengaluru
# 6          pathu   22      hebri
# 3          mithu   22      hebri
# 5        manvith   30    Germany
# 0  chandrashekar   29  Bengaluru

# %%
df.sort_values(by=['age','Location'],ascending=[True,False])
# Out:
#             Name  age   Location
# 6          pathu   22      hebri
# 3          mithu   22      hebri
# 1     rajashekar   26  Bengaluru
# 2      ravikiran   28  Bengaluru
# 0  chandrashekar   29  Bengaluru
# 4         ritesh   30      udupi
# 5        manvith   30    Germany

# %%
df['age'].nlargest(2)
# Out:
# 4    30
# 5    30
# Name: age, dtype: int64

# %%
df.nlargest(3,'age')
# Out:
#             Name  age   Location
# 4         ritesh   30      udupi
# 5        manvith   30    Germany
# 0  chandrashekar   29  Bengaluru

# %%
#grouping and aggregation

# %%
df['age'].median()
# Out:
# 28.0

# %%
df.median()
# Out:
# age    28.0
# dtype: float64

# %%
df.describe()
# Out:
#              age
# count   7.000000
# mean   26.714286
# std     3.498299
# min    22.000000
# 25%    24.000000
# 50%    28.000000
# 75%    29.500000
# max    30.000000

# %%
df['age'].count() #counts only non nan values
# Out:
# 7

# %%
df.count()
# Out:
# Name        7
# age         7
# Location    7
# dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Bengaluru    3
# hebri        2
# Germany      1
# udupi        1
# Name: Location, dtype: int64

# %%
df1 = df['Location'].value_counts(normalize=True)  # convert to percentage

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
_=ax.pie(df['Location'].value_counts(normalize=True),labels =['Bengaluru','hebri','udupi','germany'] ,autopct='%1.2f%%' ) #,autopct='%1.2f%%'

# %%
df
# Out:
#             Name  age   Location
# 4         ritesh   30      udupi
# 2      ravikiran   28  Bengaluru
# 1     rajashekar   26  Bengaluru
# 6          pathu   22      hebri
# 3          mithu   22      hebri
# 5        manvith   30    Germany
# 0  chandrashekar   29  Bengaluru

# %%
 loc_group= df.groupby(['Location'])

# %%
loc_group.get_group('Bengaluru')
# Out:
#             Name  age   Location
# 2      ravikiran   28  Bengaluru
# 1     rajashekar   26  Bengaluru
# 0  chandrashekar   29  Bengaluru

# %%
loc_group['Name'].value_counts()
# Out:
# Location   Name
# Bengaluru  chandrashekar    1
#            rajashekar       1
#            ravikiran        1
# Germany    manvith          1
# hebri      mithu            1
#            pathu            1
# udupi      ritesh           1
# Name: Name, dtype: int64

# %%
loc_group['age'].value_counts().loc['hebri']
# Out:
# age
# 22    2
# Name: age, dtype: int64

# %%
loc_group['Name'].value_counts().loc['Bengaluru']
# Out:
# Name
# chandrashekar    1
# rajashekar       1
# ravikiran        1
# Name: Name, dtype: int64

# %%
loc_group['age'].agg('median')  # aggregate function which will do median
# Out:
# Location
# Bengaluru    28
# Germany      30
# hebri        22
# udupi        30
# Name: age, dtype: int64

# %%
loc_group['age'].agg(['median','mean']) # aggregate function which will do median and mean
# Out:
#            median       mean
# Location
# Bengaluru      28  27.666667
# Germany        30  30.000000
# hebri          22  22.000000
# udupi          30  30.000000

# %%
loc_group['age'].agg(['mean','median']).loc['Bengaluru']
# Out:
# mean      27.666667
# median    28.000000
# Name: Bengaluru, dtype: float64

# %%
df.corr()
# Out:
#      age
# age  1.0

# %%
# df =pd.concate([df1,df2])

# %%
#df=pd.rename(columns={'Names':'FirstNamne'})

# %%
#Handling Missing Data

df = pd.read_csv('D:/Chandrashekar S/New Volume/Machine learning/Pandas/food-consumption.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-b70e133dec32> in <module>
#       1 #Handling Missing Data
#       2
# ----> 3 df = pd.read_csv('D:/Chandrashekar S/New Volume/Machine learning/Pandas/food-consumption.csv')
#       4 df.head()
#
# ...

# %%
df.info()

# %%
df.dropna(axis='index',how='any')  #axis = 'index' it drops rows if its 'columns' then it drops column
# if how='all' then it drops if all values in axis(index or colmn)  are null

# %%
df.dropna(axis='index',how='all')

# %%
df.dropna(axis='index',how='any',subset=['Biscuits'])  #only drops Biscuits column has null with condition how 

 #condition how means wheather to delete if entire values  which is  all or any values

# %%
# if any missing value is string written like 'NA' 'Missing' instead of NaN
df.replace(['NA','missing'],np.nan,inplace=True) #this will replace those to NaN
df
#df = pd.read_csv('../.csv', index_col='Country',na_values=['NA','Missing']) #another way to replace while reading csv

# %%
df.isnull()

# %%
df.isna()

# %%
df.fillna('MISSING') #replace NaN value to 'Missing'

# %%
df.fillna(0)

# %%
df.dtypes

# %%
type(np.nan)

# %%
df['Potatoes'] = df['Potatoes'].astype(float)
df

# %%
df['Country'].value_counts()

# %%
df['Sweetener'].unique()

# %%
df['Country'].replace('Germany',0)

# %%
#date and Time series

# %%
df = pd.read_csv('D:/Chandrashekar S/New Volume/Machine learning/Datasets/Time Series/ETH_1h.csv')
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23674 non-null  object
#  1   Symbol  23674 non-null  object
#  2   Open    23674 non-null  float64
#  3   High    23674 non-null  float64
#  4   Low     23674 non-null  float64
#  5   Close   23674 non-null  float64
#  6   Volume  23674 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.3+ MB

# %%
df.loc[0,'Date']
# Out:
# '2020-03-13 08-PM'

# %%
df.loc[0,'Date'].day_name() # error because of value in dt are sting(objects)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-3202b5406fb2> in <module>
# ----> 1 df.loc[0,'Date'].day_name() # error because of value in dt are sting(objects)
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'])  #format of date can be changed ref pandas doc
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855         try:
# -> 1856             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1857             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-124-fa7467f8385c> in <module>
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])  #format of date can be changed ref pandas doc
#       2 df.dtypes
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')  
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv('D:/Chandrashekar S/New Volume/Machine learning/Datasets/Time Series/ETH_1h.csv',
                   parse_dates=['Date'],date_parser=d_parser)
df.head(3)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81

# %%
df.loc[0,'Date'].day_name() #convert to day
# Out:
# 'Friday'

# %%
df['Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-bf15e7ad69f1> in <module>
# ----> 1 df['Date'].day_name()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'day_name'

# %%
df['Date'].dt.day_name() #dt class is similar to str class
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['Dayoftheweek']=df['Date'].dt.day_name() # add new column
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       Dayoftheweek
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].describe()
# Out:
# count                   23674
# unique                  23674
# top       2017-09-18 20:00:00
# freq                        1
# first     2017-07-01 11:00:00
# last      2020-03-13 20:00:00
# Name: Date, dtype: object

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df['Date'] >= '2020')
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#      Dayoftheweek
# 0          Friday
# ...

# %%
filt = (df['Date'] >= '2019') & (df['Date'] < '2020')
                                 
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Dayoftheweek
# ...

# %%
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
                                 
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Dayoftheweek
# ...

# %%
df.set_index('Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-194fed42a401> in <module>
# ----> 1 df.set_index('Date', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     Dayoftheweek
# Date
# 2020-03-13 20:00:00       Friday
# ...

# %%
df['2019']  # dates which are in index can be easy accessed  
#output will be of 2019
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     Dayoftheweek
# Date
# 2019-12-31 23:00:00      Tuesday
# ...

# %%
df['2020-01':'2020-02']  # range can be acessed using slicing
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                     Dayoftheweek
# Date
# 2020-02-29 23:00:00     Saturday
# ...

# %%
df['2020-01':'2020-02']['Close'].describe()  #.mean()
# Out:
# count    1440.000000
# mean      195.165590
# std        47.896863
# min       125.630000
# 25%       160.135000
# 50%       179.145000
# 75%       233.657500
# max       286.390000
# Name: Close, dtype: float64

# %%
df['2020-01']['High'].max()
# Out:
# 186.89

# %%
df['2020-01']['High'].describe()
# Out:
# count    744.000000
# mean     155.884745
# std       16.058202
# min      126.650000
# 25%      141.797500
# 50%      161.270000
# 75%      168.420000
# max      186.890000
# Name: High, dtype: float64

# %%
df['High'].resample('D').max()  #   each Day what are the max High Values  
#resample is used to filted by data or month or sec or usec etc check the pandas docs just like resampling into desired format
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs =df['High'].resample('D').max() 
# %matplotlib inline

highs.plot()

# %%
df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
df.resample('W').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
#Read and Write Data from different sources
df['Close'].to_csv('modified.csv')

# %%
df['Close'].to_csv('modified.tsv',sep='\t')   #tab seperated value

# %%
#export to excell need to install packages
#pip install xlwt openpyxl xlrd

#3 packages xlwt, openpyxl , xlrd

# %%
df['Close'].to_excel('modified.xlsx')

# %%
df = pd.read_excel('modified.xlsx')
df
# Out:
#                      Date   Close
# 0     2020-03-13 20:00:00  128.71
# 1     2020-03-13 19:00:00  129.94
# 2     2020-03-13 18:00:00  119.51
# 3     2020-03-13 17:00:00  124.47
# 4     2020-03-13 16:00:00  124.08
# ...                   ...     ...
# 23669 2017-07-01 15:00:00  272.57
# 23670 2017-07-01 14:00:00  265.74
# 23671 2017-07-01 13:00:00  268.79
# 23672 2017-07-01 12:00:00  274.83
# 23673 2017-07-01 11:00:00  275.01
#
# [23674 rows x 2 columns]

# %%
df.to_json('modified1.json')

# %%
df.to_json('modified1.json',orient='records',lines=True)

# %%
area = pd.read_json('modified1.json', orient='records', lines=True)
area
# Out:
#                      Date   Close
# 0     2020-03-13 20:00:00  128.71
# 1     2020-03-13 19:00:00  129.94
# 2     2020-03-13 18:00:00  119.51
# 3     2020-03-13 17:00:00  124.47
# 4     2020-03-13 16:00:00  124.08
# ...                   ...     ...
# 23669 2017-07-01 15:00:00  272.57
# 23670 2017-07-01 14:00:00  265.74
# 23671 2017-07-01 13:00:00  268.79
# 23672 2017-07-01 12:00:00  274.83
# 23673 2017-07-01 11:00:00  275.01
#
# [23674 rows x 2 columns]

# %%
# for using sql files packages has to be insatlled
# pip install SQLAlchemy
# pip install psycopg2-binary

# %%
from sqlalchemy import create_engine  #connect to database
#import psycopg2

#engine = create_engine('postgresql://username:pwd@localhost:4040/sample_db') 
#df.to_sql('sample_table',engine,if_exists='replace')  exists= append etc check doc

# %%
#df = pd.read_sql('sample_db',engine,index_col='Date')
#df = pd.read_sql_query('SELECT * FROM table',engine) reading Query

# %%
#df = pd.read_json('url') # to get json data from url
