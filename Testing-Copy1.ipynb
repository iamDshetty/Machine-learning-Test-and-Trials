# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression

data = {'age':[22,23,34,35],'sal':[2000,3000,4000,5000]}
test = {'age':[22,23,34,35],'sal':[2000,3000,4000,5000]}
df = pd.DataFrame(data)

lr = LogisticRegression()
x = df["age"]
y=df['sal']
x = pd.DataFrame(x)
y= pd.DataFrame(y)

lr.fit(x,y)
lr.score(x,y)
#lr.coef_
#sns.heatmap(df.isna())
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %%
dftest = pd.DataFrame(test)
a = dftest['age']
b = dftest['sal']
a = pd.DataFrame(a)
b= pd.DataFrame(b)

yp = lr.predict(a)
yp
# Out:
# array([2000, 3000, 4000, 5000], dtype=int64)

# %%
from sklearn.metrics import r2_score
r2s = r2_score(b,yp)
r2s
# Out:
# 1.0

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.0 KB

# %%
df.corr() # -1 to +1 only numbers not categorical
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x='tip',y="total_bill",data=df,kind='hex')  # kind = "hex" hexagonal shap  "reg" regression line

# %%
sns.pairplot(df) #integer value

# %%
sns.pairplot(df,hue='sex') #with categorical as hue

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.distplot(df['tip'],kde=False,bins=10) #kernal density estimation = kde ==true it shows percentage
