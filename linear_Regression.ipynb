# %%
#Linear Regression : y=mx+C
#multiple Regression : y=m1x1+m2mx2+....+C

#import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv("D:/Chandrashekar S/New Volume/Machine learning/Mathematics  in Python/Linear Regression/datasets/insurance.csv") #.dropna()

#Analyse the Dataset

#df.describe()  #to get count, mean, std devition,min, max and percentage of each features
#df.info(memory_usage='deep')  #dataset information with memory usage

#df.isna().count() # counts 

#df.sum() or df.min() ..this is usefull to check if each numeric column has null value since sum of null will be an error,NaN =non numerical Null=empty
#df.head() # print first 5 rows.. tail() last 5 rows
#df.columns # to print all  the columns header
#df.select_dtypes(exclude=["object"]) #selection based on their data types qith exclude and include
#df.isnull()  # return true if any null value
#df.notnull()  #return false if any null value

#sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
X_all = df.iloc[:,:-1]
X = X_all.select_dtypes(exclude=["object"])

y = df.iloc[:,-1]

# %%
colors=["red","blue","green"]
fig,(ax) = plt.subplots()
for i in range(len(X.columns)):
    _=ax.scatter(X.iloc[:,i],y,label=X.columns[i],color="white",edgecolor=colors[i],alpha=0.8)
    
_=ax.legend()

#looking at visualization graph
#Each feature is linear in nature

# %%
#Lets calcualte best fit line for each feature

fig,axs= plt.subplots(6,  sharey=True,figsize=(10,40))
#fig= plt.figure(figsize=(1000,800))
for x in range(len(X_all.columns)):
    _=axs[x].scatter(X_all.iloc[:,x],y,label=X_all.columns[x])
    _=axs[x].legend()
    _=axs[x].set(xlabel=X_all.columns[x],ylabel="Charges")
#_=ax.scatter(df.iloc[:,0],y,label=df.columns[0])
